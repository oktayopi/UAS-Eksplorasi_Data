# %% [markdown]
# # Eksplorasi & Visualisasi Data

# %% [markdown]
# Sumber Dataset: https://www.kaggle.com/arashnic/covid19-case-surveillance-public-use-dataset.

# %% [markdown]
# Langkah 1 - Import Modules

# %%
import pandas as pd

# %% [markdown]
# Langkah 2 - Definisikan variabel & import data dari file lokal

# %%
path = "D:\S2 Maranatha - 2021\Covid-19 Case Surveillance Public Use Dataset\COVID-19_Case_Surveillance_Public_Use_Data.csv"
df = pd.read_csv(path)
# Out:
# C:\Users\Windows10\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# Langkah 3 - Eksplorasi Data

# %%
df.head() #cek data 5 baris teratas
# Out:
#   cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# 0    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 1    2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 2    2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case  Male
# 3    2020/11/14  2020/11/10         NaN  Laboratory-confirmed case  Male
# 4    2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
#
#        age_group Race and ethnicity (combined)  hosp_yn   icu_yn death_yn  \
# 0  10 - 19 Years           Black, Non-Hispanic       No  Unknown       No
# 1  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 2  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 3  10 - 19 Years           Black, Non-Hispanic  Missing  Missing       No
# 4  10 - 19 Years           Black, Non-Hispanic       No       No       No
#
#   medcond_yn
# 0         No
# 1         No
# 2         No
# 3    Missing
# ...

# %%
df.tail() #cek data 5 baris terbawah
# Out:
#         cdc_report_dt pos_spec_dt onset_dt             current_status  \
# 8405074    2020/10/22         NaN      NaN              Probable Case
# 8405075    2020/10/25         NaN      NaN  Laboratory-confirmed case
# 8405076    2020/07/18         NaN      NaN  Laboratory-confirmed case
# 8405077    2020/11/19         NaN      NaN  Laboratory-confirmed case
# 8405078    2020/11/03         NaN      NaN  Laboratory-confirmed case
#
#              sex      age_group Race and ethnicity (combined)  hosp_yn  \
# 8405074  Missing  30 - 39 Years                       Unknown       No
# 8405075  Missing  30 - 39 Years                       Unknown  Missing
# 8405076  Missing  30 - 39 Years                       Unknown  Missing
# 8405077  Missing  30 - 39 Years                       Unknown  Missing
# 8405078  Missing  30 - 39 Years                       Unknown       No
#
#           icu_yn death_yn medcond_yn
# 8405074  Unknown       No    Missing
# 8405075  Missing  Missing    Missing
# ...

# %%
df.columns #Untuk mengetahui judul kolom yang ada dalam data set
# Out:
# Index(['cdc_report_dt', 'pos_spec_dt', 'onset_dt', 'current_status', 'sex',
#        'age_group', 'Race and ethnicity (combined)', 'hosp_yn', 'icu_yn',
#        'death_yn', 'medcond_yn'],
#       dtype='object')

# %%
df.shape #Untuk mengetahui berapa banyak baris dan kolom
# Out:
# (8405079, 11)

# %%
df.dtypes #Untuk mengetahui tipe data
# Out:
# cdc_report_dt                    object
# pos_spec_dt                      object
# onset_dt                         object
# current_status                   object
# sex                              object
# age_group                        object
# Race and ethnicity (combined)    object
# hosp_yn                          object
# icu_yn                           object
# death_yn                         object
# medcond_yn                       object
# dtype: object

# %%
df.info() #Untuk mengetahui info tipe data pada masing-masing kolom
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8405079 entries, 0 to 8405078
# Data columns (total 11 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   cdc_report_dt                  object
#  1   pos_spec_dt                    object
#  2   onset_dt                       object
#  3   current_status                 object
#  4   sex                            object
#  5   age_group                      object
#  6   Race and ethnicity (combined)  object
#  7   hosp_yn                        object
#  8   icu_yn                         object
#  9   death_yn                       object
#  10  medcond_yn                     object
# dtypes: object(11)
# memory usage: 705.4+ MB

# %%
df.isna().values.any() #Untuk mengetahui keberadaan nilai kosong
# Out:
# True

# %%
df.describe() #Untuk mendeskripsikan data
# Out:
#        cdc_report_dt pos_spec_dt    onset_dt             current_status  \
# count        8405079     2870789     4395957                    8405079
# unique           321         313         338                          2
# top       2020/06/24  2020/11/09  2020/11/02  Laboratory-confirmed case
# freq          155857       50595       49527                    7910118
#
#             sex      age_group Race and ethnicity (combined)  hosp_yn  \
# count   8405061        8404990                       8405072  8405079
# unique        5             10                             9        4
# top      Female  20 - 29 Years                       Unknown       No
# freq    4340898        1635264                       2781176  3502556
#
#          icu_yn death_yn medcond_yn
# count   8405079  8405079    8405079
# unique        4        4          4
# top     Missing       No    Missing
# freq    6178281  3690813    6063390

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Langkah 4 - Visualisasi Data

# %%
df['age_group'].value_counts().plot.bar() #Membuat diagram batang berdasar kolom grup umur
plt.tight_layout()
plt.show()

# %%
df['Race and ethnicity (combined)'].value_counts().plot.pie(autopct='%1.1f%%', labels=None, legend=True)
plt.tight_layout() #Membuat diagram pie berdasar kolom ras dan etnis

# %%
df['sex'].value_counts().plot.pie(autopct='%1.1f%%', labels=None, legend=True)
plt.tight_layout() #Membuat diagram pie berdasar jenis kelamin

# %%
from sklearn.model_selection import train_test_split #Untuk membagi dataset menjadi testing dan training
from sklearn.metrics import accuracy_score,confusion_matrix,  #Untuk evaluasi performa model

# %%
X = df.drop(columns='death_yn')
X.head()
# Out:
#   cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# 0    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 1    2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 2    2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case  Male
# 3    2020/11/14  2020/11/10         NaN  Laboratory-confirmed case  Male
# 4    2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
#
#        age_group Race and ethnicity (combined)  hosp_yn   icu_yn medcond_yn
# 0  10 - 19 Years           Black, Non-Hispanic       No  Unknown         No
# 1  10 - 19 Years           Black, Non-Hispanic       No       No         No
# 2  10 - 19 Years           Black, Non-Hispanic       No       No         No
# 3  10 - 19 Years           Black, Non-Hispanic  Missing  Missing    Missing
# 4  10 - 19 Years           Black, Non-Hispanic       No       No        Yes

# %%
y = df['death_yn']
y.head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: death_yn, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=10)

print('training dataset')
print(X_train.shape)
print(y_train.shape)
print()
print('testing dataset:')
print(X_test.shape)
print(y_test.shape)
# Out:
# training dataset
# (5043047, 10)
# (5043047,)
#
# testing dataset:
# (3362032, 10)
# (3362032,)
